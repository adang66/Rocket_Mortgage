# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pylab as plt

df = pd.read_csv('train.csv')
print ("Number of Columns: ", df.shape[1])
print ("Number of Rows: ", df.shape[0])
# Out:
# Number of Columns:  28
# Number of Rows:  316970

# %%
# Drop the 'Unnamed: 0' column
df = df.drop(columns=['Unnamed: 0'])

# %%
# Fill missing values with 'Unknown' for categorical columns
df['emp_title'] = df['emp_title'].fillna('Unknown')
df['title'] = df['title'].fillna('Unknown')

# Fill missing values for emp_length with '< 1 year'
df['emp_length'] = df['emp_length'].fillna('< 1 year')

# Drop rows with missing values for these
df = df.dropna(subset=['revol_util', 'mort_acc', 'pub_rec_bankruptcies'])

# %%
print ("Number of Columns: ", df.shape[1])
print ("Number of Rows: ", df.shape[0])
# Out:
# Number of Columns:  27
# Number of Rows:  286584

# %%
import datetime
from dateutil.relativedelta import relativedelta

target_date = datetime.datetime(2025, 3, 1)

# Month name to number mapping
month_map = {
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
}

# Function to parse dates in MON-YR format and calculate months difference
def calculate_months_from_mar_2025(date_str):
    parts = date_str.split('-')
    month = month_map[parts[0]]
    year = int(parts[1])
    
    # Handle 2-digit years
    if year < 25:
        year += 2000  # Assume 20xx for years less than 25
    elif year < 100:
        year += 1900  # Assume 19xx for years between 25 and 99
    
    date_from = datetime.datetime(year, month, 1)
    diff = relativedelta(target_date, date_from)
    return diff.years * 12 + diff.months

# Calculate months difference from each date to the target date
df['cr_months_from_mar_2025'] = df['earliest_cr_line'].apply(calculate_months_from_mar_2025)

df[['cr_months_from_mar_2025', 'earliest_cr_line']]
# Out:
#         cr_months_from_mar_2025 earliest_cr_line
# 0                           256         Nov-2003
# 1                           309         Jun-1999
# 2                           317         Oct-1998
# 3                           303         Dec-1999
# 4                           440         Jul-1988
# ...                         ...              ...
# 316964                      588         Mar-1976
# 316965                      294         Sep-2000
# 316966                      271         Aug-2002
# 316967                      282         Sep-2001
# 316969                      297         Jun-2000
#
# [286584 rows x 2 columns]

# %%
df['issue_months_from_mar_2025'] = df['issue_d'].apply(calculate_months_from_mar_2025)

df[['issue_months_from_mar_2025', 'issue_d']]
# Out:
#         issue_months_from_mar_2025   issue_d
# 0                              137  Oct-2013
# 1                              133  Feb-2014
# 2                              108  Mar-2016
# 3                              136  Nov-2013
# 4                              150  Sep-2012
# ...                            ...       ...
# 316964                         136  Nov-2013
# 316965                         124  Nov-2014
# 316966                         117  Jun-2015
# 316967                         115  Aug-2015
# 316969                         118  May-2015
#
# [286584 rows x 2 columns]

# %%
df['cr_months_from_mar_2025'].describe()
# Out:
# count    286584.000000
# mean        320.644534
# std          86.886285
# min         137.000000
# 25%         261.000000
# 50%         304.000000
# 75%         364.000000
# max         974.000000
# Name: cr_months_from_mar_2025, dtype: float64

# %%
df['issue_months_from_mar_2025'].describe()
# Out:
# count    286584.000000
# mean        129.030260
# std          12.849471
# min          99.000000
# 25%         119.000000
# 50%         129.000000
# 75%         139.000000
# max         156.000000
# Name: issue_months_from_mar_2025, dtype: float64

# %%
# Define target variable
y_target = df['loan_status']
y_target = df['loan_status'].map({'Charged Off': 1, 'Fully Paid': 0})


# Define feature set, excluding 'loan_status' and 'grade' (already in 'sub_grade')
X_features = df.drop(columns=['loan_status', 'grade', 'issue_d', 'earliest_cr_line', 'address', 'emp_title', 'title', 'issue_d', 'earliest_cr_line'])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler

# Define categorical feature groups
onehot_ftrs = ['term', 'home_ownership', 'verification_status', 
               'purpose', 'initial_list_status', 
               'application_type']

ordinal_ftrs = ['sub_grade', 'emp_length']
ordinal_cats = [['G5', 'G4', 'G3', 'G2', 'G1', 'F5', 'F4', 'F3', 'F2', 'F1', 
                 'E5', 'E4', 'E3', 'E2', 'E1', 'D5', 'D4', 'D3', 'D2', 'D1', 
                 'C5', 'C4', 'C3', 'C2', 'C1', 'B5', 'B4', 'B3', 'B2', 'B1', 
                 'A5', 'A4', 'A3', 'A2', 'A1'], 
                ['< 1 year', '1 year', '2 years', '3 years', '4 years', 
                 '5 years', '6 years', '7 years', '8 years', '9 years', '10+ years']]

minmax_ftrs = ['loan_amnt', 'int_rate', 'installment', 'dti', 
               'open_acc', 'pub_rec', 'revol_util', 'total_acc', 
               'mort_acc', 'pub_rec_bankruptcies', 'cr_months_from_mar_2025', 'issue_months_from_mar_2025']

standard_ftrs = ['annual_inc', 'revol_bal']

print("OneHot Features:", len(onehot_ftrs))
print("Ordinal Features:", len(ordinal_ftrs))
print("MinMax Features:", len(minmax_ftrs))
print("Standard Features:", len(standard_ftrs))

# Define preprocessor correctly
preprocessor = ColumnTransformer(
    transformers=[
        ('ord', OrdinalEncoder(categories=ordinal_cats), ordinal_ftrs),
        ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), onehot_ftrs),
        ('minmax', MinMaxScaler(), minmax_ftrs),
        ('standard', StandardScaler(), standard_ftrs) 
    ])

# Define pipeline correctly
clf = Pipeline(steps=[('preprocessor', preprocessor)])



# Fit and transform the data using the correct pipeline
X_transformed = clf.named_steps['preprocessor'].fit_transform(X_features)

# Get the shape of the transformed X
print("Shape of the transformed X:", X_transformed.shape)
# Out:
# OneHot Features: 6
# Ordinal Features: 2
# MinMax Features: 12
# Standard Features: 2
# Shape of the transformed X: (286584, 46)

# %%
import numpy as np

# Get feature names for each transformer in ColumnTransformer
ordinal_names = preprocessor.transformers_[0][1].get_feature_names_out(ordinal_ftrs)
onehot_names = preprocessor.transformers_[1][1].get_feature_names_out(onehot_ftrs)
minmax_names = np.array(minmax_ftrs)  
standard_names = np.array(standard_ftrs)  

# Concatenate all feature names
all_feature_names = np.concatenate([ordinal_names, onehot_names, minmax_names, standard_names])

# Print the feature names
print("Transformed Feature Names (X_transformed):")
for i, name in enumerate(all_feature_names, 1):
    print(f"{i}. {name}")
# Out:
# Transformed Feature Names (X_transformed):
# 1. sub_grade
# 2. emp_length
# 3. term_ 36 months
# 4. term_ 60 months
# 5. home_ownership_ANY
# 6. home_ownership_MORTGAGE
# 7. home_ownership_NONE
# 8. home_ownership_OTHER
# 9. home_ownership_OWN
# 10. home_ownership_RENT
# 11. verification_status_Not Verified
# 12. verification_status_Source Verified
# 13. verification_status_Verified
# 14. purpose_car
# 15. purpose_credit_card
# 16. purpose_debt_consolidation
# 17. purpose_educational
# 18. purpose_home_improvement
# 19. purpose_house
# 20. purpose_major_purchase
# 21. purpose_medical
# 22. purpose_moving
# 23. purpose_other
# 24. purpose_renewable_energy
# 25. purpose_small_business
# 26. purpose_vacation
# 27. purpose_wedding
# 28. initial_list_status_f
# 29. initial_list_status_w
# 30. application_type_DIRECT_PAY
# 31. application_type_INDIVIDUAL
# 32. application_type_JOINT
# 33. loan_amnt
# 34. int_rate
# 35. installment
# 36. dti
# 37. open_acc
# 38. pub_rec
# 39. revol_util
# 40. total_acc
# 41. mort_acc
# 42. pub_rec_bankruptcies
# 43. cr_months_from_mar_2025
# 44. issue_months_from_mar_2025
# 45. annual_inc
# 46. revol_bal

# %%
import numpy as np
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# Define the number of random states
nr_states = 5
test_scores = np.zeros(nr_states)
final_models = []

# Loop through different random states
for i in range(nr_states):
    print('Random state ' + str(i+1))
    
    # First split: Training and remaining dataset (Stratified)
    X_train, X_other, y_train, y_other = train_test_split(
        X_transformed, y_target, train_size=0.6, random_state=42+i, stratify=y_target
    )
    
    # Second split: Validation and test set (Stratified)
    X_val, X_test, y_val, y_test = train_test_split(
        X_other, y_other, train_size=0.5, random_state=42+i, stratify=y_other
    )
    
    # Define hyperparameter grid
    param_grid = {
        'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
        'penalty': ['l1', 'l2'],
        'solver': ['liblinear']  # 'liblinear' supports both l1 and l2 penalties
    }
    
    # Store validation scores
    val_scores = np.zeros(len(ParameterGrid(param_grid)))
    models = []
    
    # Loop through hyperparameter combinations
    for p, params in enumerate(ParameterGrid(param_grid)):
        print('  ', params)
        clf = LogisticRegression(**params, random_state=42+i, class_weight='balanced', max_iter=1000)
        clf.fit(X_train, y_train)
        
        # Predictions and F1 score calculations
        y_train_pred = clf.predict(X_train)
        y_val_pred = clf.predict(X_val)
        
        train_score = f1_score(y_train, y_train_pred, average='weighted')
        val_scores[p] = f1_score(y_val, y_val_pred, average='weighted')
        
        print('  Train F1 Score:', train_score, 'Validation F1 Score:', val_scores[p])
        models.append(clf)
    
    # Select the best model based on validation F1 score
    best_model_idx = np.argmax(val_scores)
    final_models.append(models[best_model_idx])
    print('Best model parameters:', ParameterGrid(param_grid)[best_model_idx])
    print('Corresponding validation F1 score:', np.max(val_scores))
    
    # Evaluate the best model on the test set
    y_test_pred = final_models[-1].predict(X_test)
    test_scores[i] = f1_score(y_test, y_test_pred, average='weighted')
    print('Test F1 score:', test_scores[i])

# Display final test scores
print('Final test F1 scores:', test_scores)
# Out:
# Random state 1
#    {'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.6988430509283448 Validation F1 Score: 0.6992948714150761
#    {'C': 0.001, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.6950163961258269 Validation F1 Score: 0.6958566903294121
#    {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.6942669106857882 Validation F1 Score: 0.6943690384430652
#    {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.6960455713437255 Validation F1 Score: 0.6959842766844593
#    {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7024106767992642 Validation F1 Score: 0.7026361031931873
#    {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.700673281109374 Validation F1 Score: 0.7003075299073298
#    {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7049653605229952 Validation F1 Score: 0.7057429272880819
#    {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7031248973844776 Validation F1 Score: 0.7036518347501644
#    {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7047980020053363 Validation F1 Score: 0.7055350477864736
#    {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7040580626562039 Validation F1 Score: 0.705028698558219
#    {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7047580341971021 Validation F1 Score: 0.7056328622407548
#    {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7055434783345116 Validation F1 Score: 0.7058040483498031
#    {'C': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7047474376151697 Validation F1 Score: 0.7056181802301745
#    {'C': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7051684722130668 Validation F1 Score: 0.7060977295258863
# Best model parameters: {'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# Corresponding validation F1 score: 0.7060977295258863
# Test F1 score: 0.7092409908786427
# Random state 2
#    {'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.6998870342264721 Validation F1 Score: 0.7020911848239276
#    {'C': 0.001, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.6958965997090958 Validation F1 Score: 0.6980351017567258
#    {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.6949500592038294 Validation F1 Score: 0.696700454586967
#    {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.696241049567863 Validation F1 Score: 0.698107765004107
#    {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7020796359955241 Validation F1 Score: 0.7041262478608927
#    {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7007268102271847 Validation F1 Score: 0.7025455666282913
#    {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7048274693585299 Validation F1 Score: 0.7077011404030684
#    {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7032854938286119 Validation F1 Score: 0.7055000889630417
#    {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.704779777295194 Validation F1 Score: 0.706571114680458
#    {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7041200795235322 Validation F1 Score: 0.7059888193709069
#    {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7047301266109123 Validation F1 Score: 0.7066007311417508
#    {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.705389323904431 Validation F1 Score: 0.708176311781668
#    {'C': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7047252263811947 Validation F1 Score: 0.7066472038538973
#    {'C': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7049383061943776 Validation F1 Score: 0.7069550555549785
# Best model parameters: {'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# Corresponding validation F1 score: 0.708176311781668
# Test F1 score: 0.7062613322315874
# Random state 3
#    {'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7008735541653985 Validation F1 Score: 0.6998932229088509
#    {'C': 0.001, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.6967235622385838 Validation F1 Score: 0.6969265157646795
#    {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.6955856079842208 Validation F1 Score: 0.6963261308408485
#    {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.6969860604401117 Validation F1 Score: 0.6966875734756346
#    {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7031395650674749 Validation F1 Score: 0.7019667548171751
#    {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7015773809448232 Validation F1 Score: 0.7004940984952275
#    {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7059070097308159 Validation F1 Score: 0.7046232510498743
#    {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7046114908081922 Validation F1 Score: 0.7028138366955441
#    {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7058174390694455 Validation F1 Score: 0.7049168270066584
#    {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7054374976250314 Validation F1 Score: 0.7033024293831688
#    {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7058515326709468 Validation F1 Score: 0.7049192087494285
#    {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.70625961981702 Validation F1 Score: 0.7055003898806169
#    {'C': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7058613285637004 Validation F1 Score: 0.7049068894083721
#    {'C': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7060114638891647 Validation F1 Score: 0.7052767396257128
# Best model parameters: {'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
# Corresponding validation F1 score: 0.7055003898806169
# Test F1 score: 0.7055805772139307
# Random state 4
#    {'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.6995324026034624 Validation F1 Score: 0.6989015147552137
#    {'C': 0.001, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.6961892672069934 Validation F1 Score: 0.6950787374265687
#    {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.6952672026253729 Validation F1 Score: 0.693778583512347
#    {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.6965740296082874 Validation F1 Score: 0.6946641857301045
#    {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7023469303419783 Validation F1 Score: 0.699427640080417
#    {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7008242043196167 Validation F1 Score: 0.6990956045970024
#    {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7050948326908844 Validation F1 Score: 0.7021528987009925
#    {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.703551297295718 Validation F1 Score: 0.7006018836133892
#    {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7048223953709382 Validation F1 Score: 0.7025734030318339
#    {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7041110059987443 Validation F1 Score: 0.7017661412080466
#    {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.704702558572808 Validation F1 Score: 0.7026074409099363
#    {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7053116464428405 Validation F1 Score: 0.7025678039488262
#    {'C': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7046829429924704 Validation F1 Score: 0.7025609548096998
#    {'C': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7053076434373655 Validation F1 Score: 0.7026977767275305
# Best model parameters: {'solver': 'liblinear', 'penalty': 'l2', 'C': 1000}
# Corresponding validation F1 score: 0.7026977767275305
# Test F1 score: 0.705641410932102
# Random state 5
#    {'C': 0.001, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7008182002909772 Validation F1 Score: 0.6981100850402469
#    {'C': 0.001, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.696954892345881 Validation F1 Score: 0.6936961409803548
#    {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.6960958087911415 Validation F1 Score: 0.6934092534098195
#    {'C': 0.01, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.6971424747544668 Validation F1 Score: 0.6952409271242451
#    {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7035577382207849 Validation F1 Score: 0.6992936413414547
#    {'C': 0.1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7018656622079447 Validation F1 Score: 0.6982643180360921
#    {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7061474144473021 Validation F1 Score: 0.7031670240789796
#    {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7048933029940582 Validation F1 Score: 0.7006016870574543
#    {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7056521855982344 Validation F1 Score: 0.7035583046747299
#    {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7058204437254443 Validation F1 Score: 0.7016782351917704
#    {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.705662894901115 Validation F1 Score: 0.7035703427987375
#    {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7065123398185315 Validation F1 Score: 0.7032138508842248
#    {'C': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
#   Train F1 Score: 0.7056685913139491 Validation F1 Score: 0.7036021263892808
#    {'C': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
#   Train F1 Score: 0.7056474367903464 Validation F1 Score: 0.7033892590114734
# Best model parameters: {'solver': 'liblinear', 'penalty': 'l1', 'C': 1000}
# Corresponding validation F1 score: 0.7036021263892808
# Test F1 score: 0.7058570362140756
# Final test F1 scores: [0.70924099 0.70626133 0.70558058 0.70564141 0.70585704]

# %%
import numpy as np
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# Define the number of random states
nr_states = 5
test_scores = np.zeros(nr_states)
final_models = []

# Loop through different random states
for i in range(nr_states):
    print('Random state ' + str(i+1))
    
    # First split: Training and remaining dataset (Stratified)
    X_train, X_other, y_train, y_other = train_test_split(
        X_transformed, y_target, train_size=0.6, random_state=42+i, stratify=y_target
    )
    
    # Second split: Validation and test set (Stratified)
    X_val, X_test, y_val, y_test = train_test_split(
        X_other, y_other, train_size=0.5, random_state=42+i, stratify=y_other
    )
    
    # Define hyperparameter grid
    param_grid = {
        'max_depth': [3, 10, 30, 100],
        'max_features': [0.25, 0.5, 0.75, 1.0]
    }
    
    # Store validation scores
    val_scores = np.zeros(len(ParameterGrid(param_grid)))
    models = []
    
    # Loop through hyperparameter combinations
    for p, params in enumerate(ParameterGrid(param_grid)):
        print('  ', params)
        clf = RandomForestClassifier(**params, random_state=42+i, n_jobs=-1, class_weight='balanced')
        clf.fit(X_train, y_train)
        
        # Predictions and F1 score calculations
        y_train_pred = clf.predict(X_train)
        y_val_pred = clf.predict(X_val)
        
        train_score = f1_score(y_train, y_train_pred, average='weighted')
        val_scores[p] = f1_score(y_val, y_val_pred, average='weighted')
        
        print('  Train F1 Score:', train_score, 'Validation F1 Score:', val_scores[p])
        models.append(clf)
    
    # Select the best model based on validation F1 score
    best_model_idx = np.argmax(val_scores)
    final_models.append(models[best_model_idx])
    print('Best model parameters:', ParameterGrid(param_grid)[best_model_idx])
    print('Corresponding validation F1 score:', np.max(val_scores))
    
    # Evaluate the best model on the test set
    y_test_pred = final_models[-1].predict(X_test)
    test_scores[i] = f1_score(y_test, y_test_pred, average='weighted')
    print('Test F1 score:', test_scores[i])

# Display final test scores
print('Final test F1 scores:', test_scores)
# Out:
# Random state 1
#    {'max_depth': 3, 'max_features': 0.25}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.5}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.75}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 1.0}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 10, 'max_features': 0.25}
#   Train F1 Score: 0.740586742252267 Validation F1 Score: 0.7303793724033548
#    {'max_depth': 10, 'max_features': 0.5}
#   Train F1 Score: 0.7468425575482024 Validation F1 Score: 0.7356623202830181
#    {'max_depth': 10, 'max_features': 0.75}
#   Train F1 Score: 0.7460137793139934 Validation F1 Score: 0.7353930522915101
#    {'max_depth': 10, 'max_features': 1.0}
#   Train F1 Score: 0.7467599357524586 Validation F1 Score: 0.7351490576536244
#    {'max_depth': 30, 'max_features': 0.25}
#   Train F1 Score: 0.999714958352141 Validation F1 Score: 0.7414947096903769
#    {'max_depth': 30, 'max_features': 0.5}
#   Train F1 Score: 0.9994530528678707 Validation F1 Score: 0.7443012760074107
#    {'max_depth': 30, 'max_features': 0.75}
#   Train F1 Score: 0.9995403688190533 Validation F1 Score: 0.7433205728594531
#    {'max_depth': 30, 'max_features': 1.0}
#   Train F1 Score: 0.9993715452225195 Validation F1 Score: 0.7446527523096818
#    {'max_depth': 100, 'max_features': 0.25}
#   Train F1 Score: 1.0 Validation F1 Score: 0.7409196099551666
#    {'max_depth': 100, 'max_features': 0.5}
#   Train F1 Score: 0.9999941843246747 Validation F1 Score: 0.7432427260810512
#    {'max_depth': 100, 'max_features': 0.75}
#   Train F1 Score: 0.9999941843246747 Validation F1 Score: 0.7436253110604397
#    {'max_depth': 100, 'max_features': 1.0}
#   Train F1 Score: 0.9999767369237544 Validation F1 Score: 0.7434641821127508
# Best model parameters: {'max_features': 1.0, 'max_depth': 30}
# Corresponding validation F1 score: 0.7446527523096818
# Test F1 score: 0.7460041865024672
# Random state 2
#    {'max_depth': 3, 'max_features': 0.25}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.5}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.75}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 1.0}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 10, 'max_features': 0.25}
#   Train F1 Score: 0.7403741278487572 Validation F1 Score: 0.7308500569753993
#    {'max_depth': 10, 'max_features': 0.5}
#   Train F1 Score: 0.7449945768786006 Validation F1 Score: 0.7351948898625907
#    {'max_depth': 10, 'max_features': 0.75}
#   Train F1 Score: 0.7449882520511091 Validation F1 Score: 0.7349536164342477
#    {'max_depth': 10, 'max_features': 1.0}
#   Train F1 Score: 0.7444945897241685 Validation F1 Score: 0.7337756503767983
#    {'max_depth': 30, 'max_features': 0.25}
#   Train F1 Score: 0.9997673242082401 Validation F1 Score: 0.7443707840542282
#    {'max_depth': 30, 'max_features': 0.5}
#   Train F1 Score: 0.9994588743710643 Validation F1 Score: 0.7448322336103248
#    {'max_depth': 30, 'max_features': 0.75}
#   Train F1 Score: 0.9994646958114153 Validation F1 Score: 0.7459844292494343
#    {'max_depth': 30, 'max_features': 1.0}
#   Train F1 Score: 0.9991036475280034 Validation F1 Score: 0.7448144329483033
#    {'max_depth': 100, 'max_features': 0.25}
#   Train F1 Score: 0.999988368586861 Validation F1 Score: 0.7426915892329427
#    {'max_depth': 100, 'max_features': 0.5}
#   Train F1 Score: 0.999988368586861 Validation F1 Score: 0.7454083010897824
#    {'max_depth': 100, 'max_features': 0.75}
#   Train F1 Score: 0.9999825527865556 Validation F1 Score: 0.744502369681463
#    {'max_depth': 100, 'max_features': 1.0}
#   Train F1 Score: 0.9999825527865556 Validation F1 Score: 0.7441016938367397
# Best model parameters: {'max_features': 0.75, 'max_depth': 30}
# Corresponding validation F1 score: 0.7459844292494343
# Test F1 score: 0.7456864020642884
# Random state 3
#    {'max_depth': 3, 'max_features': 0.25}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.5}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.75}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 1.0}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 10, 'max_features': 0.25}
#   Train F1 Score: 0.7418552588657081 Validation F1 Score: 0.7312544525320129
#    {'max_depth': 10, 'max_features': 0.5}
#   Train F1 Score: 0.7462512581362744 Validation F1 Score: 0.7341673725905733
#    {'max_depth': 10, 'max_features': 0.75}
#   Train F1 Score: 0.7472605261268265 Validation F1 Score: 0.7354170292695474
#    {'max_depth': 10, 'max_features': 1.0}
#   Train F1 Score: 0.747173121399067 Validation F1 Score: 0.7344230479111964
#    {'max_depth': 30, 'max_features': 0.25}
#   Train F1 Score: 0.9997091396103726 Validation F1 Score: 0.742857241304742
#    {'max_depth': 30, 'max_features': 0.5}
#   Train F1 Score: 0.9995636506861976 Validation F1 Score: 0.7449712442372914
#    {'max_depth': 30, 'max_features': 0.75}
#   Train F1 Score: 0.9994821597554506 Validation F1 Score: 0.7460940501810815
#    {'max_depth': 30, 'max_features': 1.0}
#   Train F1 Score: 0.9995694709960412 Validation F1 Score: 0.743932326123468
#    {'max_depth': 100, 'max_features': 0.25}
#   Train F1 Score: 0.999988368586861 Validation F1 Score: 0.7412164757346076
#    {'max_depth': 100, 'max_features': 0.5}
#   Train F1 Score: 0.9999709209984533 Validation F1 Score: 0.7436074378607899
#    {'max_depth': 100, 'max_features': 0.75}
#   Train F1 Score: 0.999988368586861 Validation F1 Score: 0.7440867868199114
#    {'max_depth': 100, 'max_features': 1.0}
#   Train F1 Score: 0.9999767369237544 Validation F1 Score: 0.7438332684475923
# Best model parameters: {'max_features': 0.75, 'max_depth': 30}
# Corresponding validation F1 score: 0.7460940501810815
# Test F1 score: 0.746753255974681
# Random state 4
#    {'max_depth': 3, 'max_features': 0.25}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.5}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.75}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 1.0}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 10, 'max_features': 0.25}
#   Train F1 Score: 0.7400125001896423 Validation F1 Score: 0.7307211762466114
#    {'max_depth': 10, 'max_features': 0.5}
#   Train F1 Score: 0.7455039056844139 Validation F1 Score: 0.7358309577791228
#    {'max_depth': 10, 'max_features': 0.75}
#   Train F1 Score: 0.7459833698618173 Validation F1 Score: 0.7354284354905384
#    {'max_depth': 10, 'max_features': 1.0}
#   Train F1 Score: 0.7460823708445391 Validation F1 Score: 0.7361794295340909
#    {'max_depth': 30, 'max_features': 0.25}
#   Train F1 Score: 0.9998022319600799 Validation F1 Score: 0.7447730234670921
#    {'max_depth': 30, 'max_features': 0.5}
#   Train F1 Score: 0.9997033208059273 Validation F1 Score: 0.7449325384053577
#    {'max_depth': 30, 'max_features': 0.75}
#   Train F1 Score: 0.9996975019388016 Validation F1 Score: 0.7449516577379844
#    {'max_depth': 30, 'max_features': 1.0}
#   Train F1 Score: 0.9996102114076222 Validation F1 Score: 0.7463826797586346
#    {'max_depth': 100, 'max_features': 0.25}
#   Train F1 Score: 0.999988368586861 Validation F1 Score: 0.7428375712804055
#    {'max_depth': 100, 'max_features': 0.5}
#   Train F1 Score: 1.0 Validation F1 Score: 0.7438597609822788
#    {'max_depth': 100, 'max_features': 0.75}
#   Train F1 Score: 0.9999941843246747 Validation F1 Score: 0.7443787963953887
#    {'max_depth': 100, 'max_features': 1.0}
#   Train F1 Score: 1.0 Validation F1 Score: 0.7449709639918017
# Best model parameters: {'max_features': 1.0, 'max_depth': 30}
# Corresponding validation F1 score: 0.7463826797586346
# Test F1 score: 0.7455466536108851
# Random state 5
#    {'max_depth': 3, 'max_features': 0.25}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.5}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 0.75}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 3, 'max_features': 1.0}
#   Train F1 Score: 0.7082177176611554 Validation F1 Score: 0.7082273740625324
#    {'max_depth': 10, 'max_features': 0.25}
#   Train F1 Score: 0.7408921103761859 Validation F1 Score: 0.7300236942296892
#    {'max_depth': 10, 'max_features': 0.5}
#   Train F1 Score: 0.7477656229200849 Validation F1 Score: 0.7349661011405535
#    {'max_depth': 10, 'max_features': 0.75}
#   Train F1 Score: 0.7486163057916403 Validation F1 Score: 0.7366617708484127
#    {'max_depth': 10, 'max_features': 1.0}
#   Train F1 Score: 0.7481020069976789 Validation F1 Score: 0.7370841007093382
#    {'max_depth': 30, 'max_features': 0.25}
#   Train F1 Score: 0.9996102114076222 Validation F1 Score: 0.743573266150542
#    {'max_depth': 30, 'max_features': 0.5}
#   Train F1 Score: 0.9994938020706653 Validation F1 Score: 0.7449722743806274
#    {'max_depth': 30, 'max_features': 0.75}
#   Train F1 Score: 0.9993715452225195 Validation F1 Score: 0.7446164931241042
#    {'max_depth': 30, 'max_features': 1.0}
#   Train F1 Score: 0.9993890121840221 Validation F1 Score: 0.7445791653088957
#    {'max_depth': 100, 'max_features': 0.25}
#   Train F1 Score: 0.9999767369237544 Validation F1 Score: 0.742677769851775
#    {'max_depth': 100, 'max_features': 0.5}
#   Train F1 Score: 0.9999767369237544 Validation F1 Score: 0.7435450460995117
#    {'max_depth': 100, 'max_features': 0.75}
#   Train F1 Score: 0.9999825527865556 Validation F1 Score: 0.744580221305713
#    {'max_depth': 100, 'max_features': 1.0}
#   Train F1 Score: 0.999959288960337 Validation F1 Score: 0.7437449672883982
# Best model parameters: {'max_features': 0.5, 'max_depth': 30}
# Corresponding validation F1 score: 0.7449722743806274
# Test F1 score: 0.7447425991859699
# Final test F1 scores: [0.74600419 0.7456864  0.74675326 0.74554665 0.7447426 ]

# %%
import numpy as np
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# Define the number of random states
nr_states = 5
test_scores = np.zeros(nr_states)
final_models = []

# Loop through different random states
for i in range(nr_states):
    print('Random state ' + str(i+1))

    # Reduce dataset size to 15% while keeping class distribution balanced (Stratified)
    X_reduced, _, y_reduced, _ = train_test_split(
        X_transformed, y_target, train_size=0.15, random_state=42+i, stratify=y_target
    )

    # First split: Training and remaining dataset (Stratified)
    X_train, X_other, y_train, y_other = train_test_split(
        X_reduced, y_reduced, train_size=0.6, random_state=42+i, stratify=y_reduced
    )

    # Second split: Validation and test set (50% of remaining → 3.75% val, 3.75% test) (Stratified)
    X_val, X_test, y_val, y_test = train_test_split(
        X_other, y_other, train_size=0.5, random_state=42+i, stratify=y_other
    )
    
    # Define hyperparameter grid for SVC
    param_grid = {
        'C': [0.1, 1, 10, 100], 
        'kernel': ['linear', 'rbf'], 
        'gamma': ['scale']
    }

    # Store validation scores
    val_scores = np.zeros(len(ParameterGrid(param_grid)))
    models = []
    
    # Loop through hyperparameter combinations
    for p, params in enumerate(ParameterGrid(param_grid)):
        print('  ', params)
        clf = SVC(**params, random_state=42+i, class_weight='balanced')
        clf.fit(X_train, y_train)
        
        # Predictions and F1 score calculations
        y_train_pred = clf.predict(X_train)
        y_val_pred = clf.predict(X_val)
        
        train_score = f1_score(y_train, y_train_pred, average='weighted')
        val_scores[p] = f1_score(y_val, y_val_pred, average='weighted')
        
        print('  Train F1 Score:', train_score, 'Validation F1 Score:', val_scores[p])
        models.append(clf)
    
    # Select the best model based on validation F1 score
    best_model_idx = np.argmax(val_scores)
    final_models.append(models[best_model_idx])
    print('Best model parameters:', ParameterGrid(param_grid)[best_model_idx])
    print('Corresponding validation F1 score:', np.max(val_scores))
    
    # Evaluate the best model on the test set
    y_test_pred = final_models[-1].predict(X_test)
    test_scores[i] = f1_score(y_test, y_test_pred, average='weighted')
    print('Test F1 score:', test_scores[i])

# Display final test scores
print('Final test F1 scores:', test_scores)
# Out:
# Random state 1
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7084246581375878 Validation F1 Score: 0.7082818180984234
#    {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
# Best model parameters: {'kernel': 'linear', 'gamma': 'scale', 'C': 0.1}
# Corresponding validation F1 score: 0.7082818180984234
# Test F1 score: 0.7081536261611088
# Random state 2
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
# Best model parameters: {'kernel': 'linear', 'gamma': 'scale', 'C': 0.1}
# Corresponding validation F1 score: 0.7082818180984234
# Test F1 score: 0.7081536261611088
# Random state 3
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7084982156669957 Validation F1 Score: 0.7085601492235899
#    {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7084982156669957 Validation F1 Score: 0.7085601492235899
#    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7084982156669957 Validation F1 Score: 0.7085601492235899
#    {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7105782290020759 Validation F1 Score: 0.7107595599233352
# Best model parameters: {'kernel': 'rbf', 'gamma': 'scale', 'C': 100}
# Corresponding validation F1 score: 0.7107595599233352
# Test F1 score: 0.7084214291439563
# Random state 4
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7089768694286551 Validation F1 Score: 0.7083298514526101
#    {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.70906933599933 Validation F1 Score: 0.7083298514526101
#    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.70906933599933 Validation F1 Score: 0.7083298514526101
#    {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7089961480648984 Validation F1 Score: 0.7083298514526101
# Best model parameters: {'kernel': 'linear', 'gamma': 'scale', 'C': 1}
# Corresponding validation F1 score: 0.7083298514526101
# Test F1 score: 0.7085368591422339
# Random state 5
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
#    {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
#   Train F1 Score: 0.7082390834804694 Validation F1 Score: 0.7082818180984234
# Best model parameters: {'kernel': 'linear', 'gamma': 'scale', 'C': 0.1}
# Corresponding validation F1 score: 0.7082818180984234
# Test F1 score: 0.7081536261611088
# Final test F1 scores: [0.70815363 0.70815363 0.70842143 0.70853686 0.70815363]

# %%
import numpy as np
from sklearn.model_selection import train_test_split, ParameterGrid
from xgboost import XGBClassifier
from sklearn.metrics import f1_score

# Define the number of random states
nr_states = 5
test_scores = np.zeros(nr_states)
final_models = []

# Loop through different random states
for i in range(nr_states):
    print('Random state ' + str(i+1))
    
    # First split: Training and remaining dataset (Stratified)
    X_train, X_other, y_train, y_other = train_test_split(
        X_transformed, y_target, train_size=0.6, random_state=42+i, stratify=y_target
    )
    
    # Second split: Validation and test set (Stratified)
    X_val, X_test, y_val, y_test = train_test_split(
        X_other, y_other, train_size=0.5, random_state=42+i, stratify=y_other
    )
    
    # Define hyperparameter grid
    param_grid = {
        'learning_rate': [0.01,0.1, 0.3],  
        'max_depth': [3, 10],  
        'n_estimators': [50, 200],   
        'min_child_weight': [1, 5], 
        'gamma': [0, 0.1, 1], 
        'reg_lambda': [1, 10]   
}
    
    # Store validation scores
    val_scores = np.zeros(len(ParameterGrid(param_grid)))
    models = []
    
    # Loop through hyperparameter combinations
    for p, params in enumerate(ParameterGrid(param_grid)):
        print('  ', params)
        clf = XGBClassifier(**params, random_state=42+i, eval_metric='logloss', scale_pos_weight=4.95)
        clf.fit(X_train, y_train)
        
        # Predictions and F1 score calculations
        y_train_pred = clf.predict(X_train)
        y_val_pred = clf.predict(X_val)
        
        train_score = f1_score(y_train, y_train_pred, average='weighted')
        val_scores[p] = f1_score(y_val, y_val_pred, average='weighted')
        
        print('  Train F1 Score:', train_score, 'Validation F1 Score:', val_scores[p])
        models.append(clf)
    
    # Select the best model based on validation F1 score
    best_model_idx = np.argmax(val_scores)
    final_models.append(models[best_model_idx])
    print('Best model parameters:', ParameterGrid(param_grid)[best_model_idx])
    print('Corresponding validation F1 score:', np.max(val_scores))
    
    # Evaluate the best model on the test set
    y_test_pred = final_models[-1].predict(X_test)
    test_scores[i] = f1_score(y_test, y_test_pred, average='weighted')
    print('Test F1 score:', test_scores[i])

# Display final test scores
print('Final test F1 scores:', test_scores)
# Out:
# Random state 1
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4669446709494083 Validation F1 Score: 0.46777383170123316
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.4664870325177484 Validation F1 Score: 0.4672613893647195
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6074757723055344 Validation F1 Score: 0.6054476160401321
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6072440190062119 Validation F1 Score: 0.6054665547136356
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4669446709494083 Validation F1 Score: 0.46777383170123316
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.4664870325177484 Validation F1 Score: 0.4672613893647195
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6074757723055344 Validation F1 Score: 0.6054476160401321
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6072440190062119 Validation F1 Score: 0.6054665547136356
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5685507588354647 Validation F1 Score: 0.5450329459428085
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5590418870089814 Validation F1 Score: 0.5382078097986993
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6844466896467694 Validation F1 Score: 0.6511698468043973
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.677289352129406 Validation F1 Score: 0.6463772927501685
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.56482660038449 Validation F1 Score: 0.5423237655063913
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.557212173863068 Validation F1 Score: 0.5379909326450621
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6821236504938042 Validation F1 Score: 0.6507773573296088
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6748861290029349 Validation F1 Score: 0.6455928761905285
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6296569203424331 Validation F1 Score: 0.6269039130863738
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6308494970744536 Validation F1 Score: 0.6278900112030514
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6461282298868227 Validation F1 Score: 0.6433605915482358
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6469038870048898 Validation F1 Score: 0.6433625096793364
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6296889591110786 Validation F1 Score: 0.6271161111739584
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6305351264996795 Validation F1 Score: 0.6274884280447697
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6460053447284958 Validation F1 Score: 0.6428725583222774
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6471795349719803 Validation F1 Score: 0.64375761879917
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7263106353135281 Validation F1 Score: 0.6748286360318634
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7139764421310029 Validation F1 Score: 0.6701174475916484
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.825117408809183 Validation F1 Score: 0.7067209879028982
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7977581248318445 Validation F1 Score: 0.6989260247127326
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7215016094960006 Validation F1 Score: 0.67317747598651
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7083233937388974 Validation F1 Score: 0.6662548127207497
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8115391880013094 Validation F1 Score: 0.7055025069311909
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7822953846218756 Validation F1 Score: 0.6954792987864931
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6461266846357474 Validation F1 Score: 0.6441013036792268
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.644397661588805 Validation F1 Score: 0.6403820186352835
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6613006003970956 Validation F1 Score: 0.6536337813516705
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6590304686810105 Validation F1 Score: 0.6523086361537106
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6458251517900088 Validation F1 Score: 0.6431276796275552
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6444581369489609 Validation F1 Score: 0.6416477162484728
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.66042541942333 Validation F1 Score: 0.6528645887100177
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6589896117653907 Validation F1 Score: 0.6518377125440953
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.797557213440231 Validation F1 Score: 0.6935403826872119
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7732449694722525 Validation F1 Score: 0.690959833096498
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.9457452256968566 Validation F1 Score: 0.7332126188445227
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9306699451748618 Validation F1 Score: 0.7331823712598571
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7750215169830925 Validation F1 Score: 0.6886920059815976
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7580807123578349 Validation F1 Score: 0.6819500041398774
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.9234866884411795 Validation F1 Score: 0.7281011025892873
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9088972385122661 Validation F1 Score: 0.7264988528261672
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4669446709494083 Validation F1 Score: 0.46777383170123316
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.4664870325177484 Validation F1 Score: 0.4672613893647195
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6074757723055344 Validation F1 Score: 0.6054476160401321
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6072440190062119 Validation F1 Score: 0.6054665547136356
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4669446709494083 Validation F1 Score: 0.46777383170123316
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.4664870325177484 Validation F1 Score: 0.4672613893647195
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6074757723055344 Validation F1 Score: 0.6054476160401321
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6072440190062119 Validation F1 Score: 0.6054665547136356
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5687181644318254 Validation F1 Score: 0.5448320600532736
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5586850689186192 Validation F1 Score: 0.5388971045514296
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6841737924804316 Validation F1 Score: 0.6507879995803327
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6770036413553908 Validation F1 Score: 0.6467025741953726
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5648654882296139 Validation F1 Score: 0.5422590030563427
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5569452435504373 Validation F1 Score: 0.5381912403901976
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6816106575300603 Validation F1 Score: 0.6502346399055986
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6753117935112756 Validation F1 Score: 0.6459692129384011
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6296569203424331 Validation F1 Score: 0.6269039130863738
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6308494970744536 Validation F1 Score: 0.6278900112030514
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6461282298868227 Validation F1 Score: 0.6433605915482358
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6469038870048898 Validation F1 Score: 0.6433625096793364
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6296889591110786 Validation F1 Score: 0.6271161111739584
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6305351264996795 Validation F1 Score: 0.6274884280447697
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6460053447284958 Validation F1 Score: 0.6428725583222774
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6471795349719803 Validation F1 Score: 0.64375761879917
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7236624227860198 Validation F1 Score: 0.6739261264495474
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7118393639090774 Validation F1 Score: 0.6684374191134701
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8262522352650986 Validation F1 Score: 0.7076302065151203
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7976431665540457 Validation F1 Score: 0.7018644052222606
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7217080225932757 Validation F1 Score: 0.6727967602828043
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7080765044754929 Validation F1 Score: 0.667286339182749
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8104124232865632 Validation F1 Score: 0.7031458166807601
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7818130261210339 Validation F1 Score: 0.695638074726128
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6461266846357474 Validation F1 Score: 0.6441013036792268
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.644397661588805 Validation F1 Score: 0.6403820186352835
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6613006003970956 Validation F1 Score: 0.6536337813516705
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6590304686810105 Validation F1 Score: 0.6523086361537106
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6458251517900088 Validation F1 Score: 0.6431276796275552
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6444581369489609 Validation F1 Score: 0.6416477162484728
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.66042541942333 Validation F1 Score: 0.6528645887100177
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6589896117653907 Validation F1 Score: 0.6518377125440953
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7903457237471349 Validation F1 Score: 0.691942076680252
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7771512889685503 Validation F1 Score: 0.691332301651663
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.9462582457464712 Validation F1 Score: 0.7353591586693436
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9319108738520758 Validation F1 Score: 0.7336408483517339
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7848451741523055 Validation F1 Score: 0.6904120982483917
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7648915936877353 Validation F1 Score: 0.6853138186656045
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.9288123445650532 Validation F1 Score: 0.7301142850200127
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9019121157142144 Validation F1 Score: 0.7262088270114977
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4669446709494083 Validation F1 Score: 0.46777383170123316
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.4664870325177484 Validation F1 Score: 0.4672613893647195
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6074757723055344 Validation F1 Score: 0.6054476160401321
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6072440190062119 Validation F1 Score: 0.6054665547136356
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4669446709494083 Validation F1 Score: 0.46777383170123316
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.4664870325177484 Validation F1 Score: 0.4672613893647195
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6074757723055344 Validation F1 Score: 0.6054476160401321
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6072440190062119 Validation F1 Score: 0.6054665547136356
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5687205149925187 Validation F1 Score: 0.5450890443010761
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5590145753432817 Validation F1 Score: 0.5390133276115664
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6843270775393742 Validation F1 Score: 0.6509510534692388
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6770265574389441 Validation F1 Score: 0.6468285044843779
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5648700632999821 Validation F1 Score: 0.5428324776868798
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5574268016428598 Validation F1 Score: 0.5383641433177931
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6821888064235873 Validation F1 Score: 0.6505990708177992
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6748227398900346 Validation F1 Score: 0.6465637558905496
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6296569203424331 Validation F1 Score: 0.6269039130863738
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6308494970744536 Validation F1 Score: 0.6278900112030514
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6461282298868227 Validation F1 Score: 0.6433605915482358
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6469038870048898 Validation F1 Score: 0.6433625096793364
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6296889591110786 Validation F1 Score: 0.6271161111739584
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6305351264996795 Validation F1 Score: 0.6274884280447697
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6460053447284958 Validation F1 Score: 0.6428725583222774
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6471795349719803 Validation F1 Score: 0.64375761879917
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.727875395924436 Validation F1 Score: 0.6757031294117166
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7125377182825757 Validation F1 Score: 0.669628961046616
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8011253990642881 Validation F1 Score: 0.7012087717015408
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7802548441343984 Validation F1 Score: 0.6951395446584865
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7215630763448178 Validation F1 Score: 0.6725390941241688
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7102315958959591 Validation F1 Score: 0.6692078523836837
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.795621641654231 Validation F1 Score: 0.6986532224495868
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7765893759328523 Validation F1 Score: 0.6936133542766092
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6461266846357474 Validation F1 Score: 0.6441013036792268
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.644397661588805 Validation F1 Score: 0.6403820186352835
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6601882896943656 Validation F1 Score: 0.6535579531272684
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6593451448156378 Validation F1 Score: 0.6522747277308604
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6458251517900088 Validation F1 Score: 0.6431276796275552
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6444581369489609 Validation F1 Score: 0.6416477162484728
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6609759595851799 Validation F1 Score: 0.6532665989399599
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6590654840820812 Validation F1 Score: 0.6512260887121806
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7976600662254153 Validation F1 Score: 0.693785893836824
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7715366471982761 Validation F1 Score: 0.6881475740864036
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8424068267124525 Validation F1 Score: 0.707142956361885
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.8144064451211347 Validation F1 Score: 0.7021015987086358
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7799725258661876 Validation F1 Score: 0.6893741880750238
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7685709452114865 Validation F1 Score: 0.687176791563286
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8513868620520971 Validation F1 Score: 0.7099772330510757
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.8080556878234298 Validation F1 Score: 0.6986026048635358
# Best model parameters: {'reg_lambda': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 10, 'learning_rate': 0.3, 'gamma': 0.1}
# Corresponding validation F1 score: 0.7353591586693436
# Test F1 score: 0.7390225703199585
# Random state 2
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4616793533785696 Validation F1 Score: 0.4638379453132251
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.459138850934971 Validation F1 Score: 0.4610774068199057
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6090267255521459 Validation F1 Score: 0.6124309390433552
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6083086343866438 Validation F1 Score: 0.6114951145949453
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4616793533785696 Validation F1 Score: 0.4638379453132251
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.459138850934971 Validation F1 Score: 0.4610774068199057
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6090267255521459 Validation F1 Score: 0.6124309390433552
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6083086343866438 Validation F1 Score: 0.6114951145949453
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5660058026999103 Validation F1 Score: 0.5503530979158558
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5573608566509163 Validation F1 Score: 0.543065820952508
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6839677889025905 Validation F1 Score: 0.6544177055763434
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6777538219695745 Validation F1 Score: 0.65176362791604
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5639335427373557 Validation F1 Score: 0.5487786258256582
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5546139660608036 Validation F1 Score: 0.5418045542251646
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6814855993351809 Validation F1 Score: 0.6548033291722936
#    {'gamma': 0, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6749304363690508 Validation F1 Score: 0.6509306766631167
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6288799637258999 Validation F1 Score: 0.6304294024147995
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6311063576265835 Validation F1 Score: 0.6324188654293349
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6468518205158449 Validation F1 Score: 0.6455204900765181
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6479818503791123 Validation F1 Score: 0.6469917520382825
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.628880993468671 Validation F1 Score: 0.630381376699894
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.631025114487658 Validation F1 Score: 0.6322184964868364
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6467102443262353 Validation F1 Score: 0.6462775816761825
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6475495948554277 Validation F1 Score: 0.6469548023924179
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7249990525399802 Validation F1 Score: 0.6781762408171955
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7124296470110347 Validation F1 Score: 0.6732400461325252
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8200909466324743 Validation F1 Score: 0.7121084497962019
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7926497326942478 Validation F1 Score: 0.7029390006408972
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7201793402871678 Validation F1 Score: 0.6779905825733433
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7073207987396833 Validation F1 Score: 0.6717868695590564
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8053080767207818 Validation F1 Score: 0.70717781602868
#    {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7800708057899621 Validation F1 Score: 0.6998085270935154
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6450739857899188 Validation F1 Score: 0.6453077517133587
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.645350835572013 Validation F1 Score: 0.64529971331151
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.659928680037777 Validation F1 Score: 0.6558015439639974
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6603692394034377 Validation F1 Score: 0.6561649519551166
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.646058797690783 Validation F1 Score: 0.6471683231919114
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6454182986692851 Validation F1 Score: 0.6456712779845742
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6601545447041411 Validation F1 Score: 0.6555877329686852
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6590003569048567 Validation F1 Score: 0.6546207458837469
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7897292061620722 Validation F1 Score: 0.6953829173537334
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7724603855174957 Validation F1 Score: 0.6922776708486751
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.9506464653290188 Validation F1 Score: 0.7363510418481024
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9254262322844855 Validation F1 Score: 0.735250212326877
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7757608949414019 Validation F1 Score: 0.6913229756992049
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7585198489520768 Validation F1 Score: 0.6891567290002549
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.9238648059077117 Validation F1 Score: 0.7307345663973599
#    {'gamma': 0, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9056837507431259 Validation F1 Score: 0.7291802151485528
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4616793533785696 Validation F1 Score: 0.4638379453132251
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.459138850934971 Validation F1 Score: 0.4610774068199057
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6090267255521459 Validation F1 Score: 0.6124309390433552
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6083086343866438 Validation F1 Score: 0.6114951145949453
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4616793533785696 Validation F1 Score: 0.4638379453132251
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.459138850934971 Validation F1 Score: 0.4610774068199057
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6090267255521459 Validation F1 Score: 0.6124309390433552
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6083086343866438 Validation F1 Score: 0.6114951145949453
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5658756533249822 Validation F1 Score: 0.5502561912559238
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5574512429671006 Validation F1 Score: 0.5433534126407171
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6839795557705556 Validation F1 Score: 0.654797826260918
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6774243681479292 Validation F1 Score: 0.6516794209304554
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5639397520453844 Validation F1 Score: 0.5487786258256582
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.55439456261122 Validation F1 Score: 0.5419448270763917
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6815743556501013 Validation F1 Score: 0.6549439618299422
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6749972707002271 Validation F1 Score: 0.6506204927457268
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6288799637258999 Validation F1 Score: 0.6304294024147995
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6311063576265835 Validation F1 Score: 0.6324188654293349
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6468518205158449 Validation F1 Score: 0.6455204900765181
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6479818503791123 Validation F1 Score: 0.6469917520382825
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.628880993468671 Validation F1 Score: 0.630381376699894
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.631025114487658 Validation F1 Score: 0.6322184964868364
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6467102443262353 Validation F1 Score: 0.6462775816761825
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6475495948554277 Validation F1 Score: 0.6469548023924179
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7250578626603753 Validation F1 Score: 0.6785351466066615
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7124096597714752 Validation F1 Score: 0.6737466311782173
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8121980566940742 Validation F1 Score: 0.7090390660756856
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7916150053471728 Validation F1 Score: 0.7025729734541041
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.720156196032183 Validation F1 Score: 0.6770564887812315
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7072371623839346 Validation F1 Score: 0.6712382084737425
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8050220620605466 Validation F1 Score: 0.7071779779392279
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7763175548411138 Validation F1 Score: 0.6985770108592575
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6450739857899188 Validation F1 Score: 0.6453077517133587
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.645350835572013 Validation F1 Score: 0.64529971331151
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6600124242108972 Validation F1 Score: 0.6546231736669039
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6603692394034377 Validation F1 Score: 0.6561649519551166
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.646058797690783 Validation F1 Score: 0.6471683231919114
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6454182986692851 Validation F1 Score: 0.6456712779845742
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6601545447041411 Validation F1 Score: 0.6555877329686852
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6590003569048567 Validation F1 Score: 0.6546207458837469
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7853244948849056 Validation F1 Score: 0.6941301916048352
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7698936538985802 Validation F1 Score: 0.6911371374559521
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.948999925366775 Validation F1 Score: 0.735601609126737
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.927313097198659 Validation F1 Score: 0.7364039938305262
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7754673275333661 Validation F1 Score: 0.6913502152734337
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7603467121837189 Validation F1 Score: 0.6896843710460433
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.927345327428364 Validation F1 Score: 0.7305115310098154
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9092980538000438 Validation F1 Score: 0.7275178184119425
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4616793533785696 Validation F1 Score: 0.4638379453132251
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.459138850934971 Validation F1 Score: 0.4610774068199057
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6090267255521459 Validation F1 Score: 0.6124309390433552
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6083086343866438 Validation F1 Score: 0.6114951145949453
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4616793533785696 Validation F1 Score: 0.4638379453132251
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.459138850934971 Validation F1 Score: 0.4610774068199057
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
# ...
#    {'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6722528789628665 Validation F1 Score: 0.6454741125744351
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6310629471068551 Validation F1 Score: 0.6274977658135115
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6310087854073179 Validation F1 Score: 0.6273866279661483
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6494856802107474 Validation F1 Score: 0.6435011622754038
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6496817486112819 Validation F1 Score: 0.6437351402402156
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.631057446928998 Validation F1 Score: 0.6274977658135115
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6310197886009209 Validation F1 Score: 0.6273866279661483
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6494328693040559 Validation F1 Score: 0.6431634054173494
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6494729111112254 Validation F1 Score: 0.6433921622848032
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7246038974464223 Validation F1 Score: 0.6747138347844924
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7097540552182849 Validation F1 Score: 0.6686055401282508
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8224702647627444 Validation F1 Score: 0.7073369295301337
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7971957771975035 Validation F1 Score: 0.70010674813048
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7190041395986881 Validation F1 Score: 0.6718936547180117
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7054851304664709 Validation F1 Score: 0.6678793368492753
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8065547997225462 Validation F1 Score: 0.703100818754083
#    {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7821452190228789 Validation F1 Score: 0.6962539054062822
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6481782469571933 Validation F1 Score: 0.642540791845149
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6467984478765946 Validation F1 Score: 0.6420600137124257
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6611704443953569 Validation F1 Score: 0.6513724649912416
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6604154963117455 Validation F1 Score: 0.6521832283830635
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6493922718343035 Validation F1 Score: 0.6443970021749718
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6478275404441469 Validation F1 Score: 0.6433292773089279
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6607132835935714 Validation F1 Score: 0.6501433987125702
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.661167687571991 Validation F1 Score: 0.6517038019501471
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7996278363376973 Validation F1 Score: 0.6924210170144345
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7655041715568555 Validation F1 Score: 0.6880029205444723
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.9481802063408873 Validation F1 Score: 0.7369555523392423
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9299619540681663 Validation F1 Score: 0.734773975901951
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7815616427340842 Validation F1 Score: 0.6903802812242577
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7651660289072242 Validation F1 Score: 0.6863936748582351
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.9300104223798689 Validation F1 Score: 0.7304748153210255
#    {'gamma': 0.1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.9107186253322259 Validation F1 Score: 0.7292809823072594
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4913619760930601 Validation F1 Score: 0.4896176395265782
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.49136872428820333 Validation F1 Score: 0.4896379120305594
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6088607860029532 Validation F1 Score: 0.6073382464176191
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.608020854888713 Validation F1 Score: 0.6066935506110388
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.4913619760930601 Validation F1 Score: 0.4896176395265782
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.49136872428820333 Validation F1 Score: 0.4896379120305594
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6088607860029532 Validation F1 Score: 0.6073382464176191
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.608020854888713 Validation F1 Score: 0.6066935506110388
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5674162431512803 Validation F1 Score: 0.5458763369889404
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5575975893476699 Validation F1 Score: 0.5399870511300752
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6824894297960605 Validation F1 Score: 0.6510134512582056
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.674222864810631 Validation F1 Score: 0.6462625261230107
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.5645965007554852 Validation F1 Score: 0.5460258954773022
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.5551398901989216 Validation F1 Score: 0.5386484538420875
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6795283981232134 Validation F1 Score: 0.6497174305832432
#    {'gamma': 1, 'learning_rate': 0.01, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6725789633662955 Validation F1 Score: 0.6461603379938446
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6310629471068551 Validation F1 Score: 0.6274977658135115
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6310087854073179 Validation F1 Score: 0.6273866279661483
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6494856802107474 Validation F1 Score: 0.6435011622754038
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6496817486112819 Validation F1 Score: 0.6437351402402156
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.631057446928998 Validation F1 Score: 0.6274977658135115
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6310197886009209 Validation F1 Score: 0.6273866279661483
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6494328693040559 Validation F1 Score: 0.6431634054173494
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6494729111112254 Validation F1 Score: 0.6433921622848032
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7239936510187852 Validation F1 Score: 0.6750450167597264
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7099273848061062 Validation F1 Score: 0.6682572244043608
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8069909534626417 Validation F1 Score: 0.7028486846859564
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7856193374929983 Validation F1 Score: 0.6967848079660994
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7209720652845378 Validation F1 Score: 0.6730706121058029
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7059395681009211 Validation F1 Score: 0.6677346187096598
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.7925284723212473 Validation F1 Score: 0.7005635599444703
#    {'gamma': 1, 'learning_rate': 0.1, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.7710954238918054 Validation F1 Score: 0.6940281941646326
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6481782469571933 Validation F1 Score: 0.642540791845149
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6467984478765946 Validation F1 Score: 0.6420600137124257
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6611704443953569 Validation F1 Score: 0.6513724649912416
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.6611321828591016 Validation F1 Score: 0.6518943505153182
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.6493922718343035 Validation F1 Score: 0.6443970021749718
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.6478275404441469 Validation F1 Score: 0.6433292773089279
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.6608664569668351 Validation F1 Score: 0.6505270577484987
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.661167687571991 Validation F1 Score: 0.6517038019501471
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.792047219367909 Validation F1 Score: 0.6932594262432599
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7711563051012938 Validation F1 Score: 0.688822496915009
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8520233952293534 Validation F1 Score: 0.7089336423222948
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 1, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.8315683584288597 Validation F1 Score: 0.7070109030936954
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 1}
#   Train F1 Score: 0.7820475663265994 Validation F1 Score: 0.6903467973196443
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 50, 'reg_lambda': 10}
#   Train F1 Score: 0.7633395660031669 Validation F1 Score: 0.6852295187139473
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 1}
#   Train F1 Score: 0.8456328766596684 Validation F1 Score: 0.7086948420616876
#    {'gamma': 1, 'learning_rate': 0.3, 'max_depth': 10, 'min_child_weight': 5, 'n_estimators': 200, 'reg_lambda': 10}
#   Train F1 Score: 0.8167052840345405 Validation F1 Score: 0.7019591071164771
# Best model parameters: {'reg_lambda': 1, 'n_estimators': 200, 'min_child_weight': 1, 'max_depth': 10, 'learning_rate': 0.3, 'gamma': 0.1}
# Corresponding validation F1 score: 0.7369555523392423
# Test F1 score: 0.738031405949086
# Final test F1 scores: [0.73902257 0.73438759 0.73558182 0.738208   0.73803141]
